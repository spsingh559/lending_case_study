# %% [markdown]
# # Lending Club Case Study

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('max_columns', None)

# %%
#read files
df = pd.read_csv('../data/loan.csv', low_memory=False)

# %%
#basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
#shape of data
df.shape
# Out:
# (39717, 111)

# %%
#view  data
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0   10.65%       162.87     B        B2                       NaN  10+ years
# 1   15.27%        59.83     C        C4                     Ryder   < 1 year
# 2   15.96%        84.33     C        C5                       NaN  10+ years
# 3   13.49%       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4   12.69%        67.79     B        B5  University Medical Group     1 year
#
# ...

# %%
#null values percentage
df.isnull().sum()*100/len(df)
# Out:
# id                              0.000000
# member_id                       0.000000
# loan_amnt                       0.000000
# funded_amnt                     0.000000
# funded_amnt_inv                 0.000000
#                                  ...
# tax_liens                       0.098195
# tot_hi_cred_lim               100.000000
# total_bal_ex_mort             100.000000
# total_bc_limit                100.000000
# total_il_high_credit_limit    100.000000
# Length: 111, dtype: float64

# %%
#remove 90% above null columns
df=df.dropna(thresh=df.shape[0]*0.9,how='all',axis=1)

# %%
# data cleaning
df['int_rate']=df['int_rate'].apply(lambda x:x.replace('%',''))

# %%
#remove months in terms
df['term']=df['term'].apply(lambda x: x.replace('months',''))

# %%
#remove current loan
df=df[(df['loan_status']!="Current")]
# Out:
# Fully Paid     32950
# Charged Off     5627
# Name: loan_status, dtype: int64

# %%
#replacing 1 with charged off and 0 with Fully Paid
df['loan_status']=df['loan_status'].apply(lambda x: 1 if x=="Charged Off" else 0)

# %%
df['loan_status'].value_counts()
# Out:
# 0    32950
# 1     5627
# Name: loan_status, dtype: int64

# %%
#Employement lenght

df['emp_length'].value_counts()
# Out:
# 10+ years    8488
# < 1 year     4508
# 2 years      4291
# 3 years      4012
# 4 years      3342
# 5 years      3194
# 1 year       3169
# 6 years      2168
# 7 years      1711
# 8 years      1435
# 9 years      1226
# Name: emp_length, dtype: int64

# %%
#shape after removing unwanted columns
df.shape
# Out:
# (39717, 54)

# %%
#glance at data frame info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          39717 non-null  int64
#  1   member_id                   39717 non-null  int64
#  2   loan_amnt                   39717 non-null  int64
#  3   funded_amnt                 39717 non-null  int64
#  4   funded_amnt_inv             39717 non-null  float64
#  5   term                        39717 non-null  object
#  6   int_rate                    39717 non-null  object
#  7   installment                 39717 non-null  float64
#  8   grade                       39717 non-null  object
#  9   sub_grade                   39717 non-null  object
#  10  emp_title                   37258 non-null  object
#  11  emp_length                  38642 non-null  object
#  12  home_ownership              39717 non-null  object
# ...

# %%
#considering only default loan for study
default=df[(df.loan_status=="Charged Off")]

# %%
#shape of default frame
default.shape
# Out:
# (5627, 54)

# %% [markdown]
# ## Relation of Univariate with loan status

# %% [markdown]
# ### Grade of borrower with default

# %%
default['grade'].value_counts()
# Out:
# B    1425
# C    1347
# D    1118
# E     715
# A     602
# F     319
# G     101
# Name: grade, dtype: int64

# %% [markdown]
# #### There is no any strong pattern between grade risk and defaulter

# %% [markdown]
# ### Loan purpose with default

# %%
default['purpose'].value_counts()
# Out:
# debt_consolidation    2767
# other                  633
# credit_card            542
# small_business         475
# home_improvement       347
# major_purchase         222
# car                    160
# medical                106
# wedding                 96
# moving                  92
# house                   59
# educational             56
# vacation                53
# renewable_energy        19
# Name: purpose, dtype: int64

# %% [markdown]
# #### debt_consolidation has highest contribution for defaulting loan, followed by other and credit card

# %% [markdown]
# ### HomeOwnership with default

# %%
default['home_ownership'].value_counts()
# Out:
# RENT        2839
# MORTGAGE    2327
# OWN          443
# OTHER         18
# Name: home_ownership, dtype: int64

# %% [markdown]
# #### People having their own home is less likely to be defaulted

# %% [markdown]
# ### Employee Exp vs default

# %%
default['emp_length'].value_counts()
# Out:
# 10+ years    1331
# < 1 year      639
# 2 years       567
# 3 years       555
# 4 years       462
# 5 years       458
# 1 year        456
# 6 years       307
# 7 years       263
# 8 years       203
# 9 years       158
# Name: emp_length, dtype: int64

# %% [markdown]
# #### People having more number of work experience has cases of default

# %%
# default[(default['revol_util']>=50)]['revol_util'].count()
# Out:
# 3330

# %%
default['revol_util'].describe()
# Out:
# count    5627.000000
# mean       55.414095
# std        28.022277
# min         0.000000
# 25%        34.300000
# 50%        58.200000
# 75%        78.950000
# max        99.900000
# Name: revol_util, dtype: float64

# %%
#dti
default['dti'].describe()
# Out:
# count    5627.000000
# mean       14.000624
# std         6.585577
# min         0.000000
# 25%         9.050000
# 50%        14.290000
# 75%        19.290000
# max        29.850000
# Name: dti, dtype: float64

# %%
#default['loan_amnt'].describe()
# Out:
# count     5627.000000
# mean     12104.385108
# std       8085.732038
# min        900.000000
# 25%       5600.000000
# 50%      10000.000000
# 75%      16500.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
#default['verification_status'].value_counts()
# Out:
# Not Verified       2142
# Verified           2051
# Source Verified    1434
# Name: verification_status, dtype: int64

# %%
default.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'acc_now_delinq', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens'],
#       dtype='object')
